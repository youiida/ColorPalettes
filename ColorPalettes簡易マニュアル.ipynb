# %%
from ColorPalettes import ColorPalettes as cp

# %% [markdown]
# # 大まかな分類の名前を出力

# %%
cp.get_group_names()
# Out:
# ['Tetracolor', 'Alt Black', 'Bicolor', 'Tricolor', 'Additional Palettes']

# %% [markdown]
# # 各グループの色見本を表示
# ## Tetracolor のpalettes
# - PIE_Decoration.plot_prediction(palette="mujirushi") # ここのpaletteで指定できる色

# %%
cp.display_group_palettes("Tetracolor")

# %% [markdown]
# ## Alt Black のpalettes

# %%
cp.display_group_palettes("Alt Black")

# %% [markdown]
# ## Bicolor のpalettes

# %%
cp.display_group_palettes("Bicolor")

# %% [markdown]
# ## Tricolor のpalettes

# %%
cp.display_group_palettes("Tricolor")

# %% [markdown]
# ## Additional Palettes のpalettes

# %%
cp.display_group_palettes("Additional Palettes")
